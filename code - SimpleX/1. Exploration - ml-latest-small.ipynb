# %% [markdown]
# # ABOUT:
# - this notebook briefly looks at the **ml-latest-small** dataset

# %%
import pandas as pd
links_path = r"C:\Users\tanch\Documents\NTU\NTU Year 4\FYP - GNN\data\ml-latest-small\ml-latest-small\links.csv"
movies_path = r"C:\Users\tanch\Documents\NTU\NTU Year 4\FYP - GNN\data\ml-latest-small\ml-latest-small\movies.csv"
ratings_path = r"C:\Users\tanch\Documents\NTU\NTU Year 4\FYP - GNN\data\ml-latest-small\ml-latest-small\ratings.csv"
tags_path = r"C:\Users\tanch\Documents\NTU\NTU Year 4\FYP - GNN\data\ml-latest-small\ml-latest-small\tags.csv"
links = pd.read_csv(links_path)
movies = pd.read_csv(movies_path)
ratings = pd.read_csv(ratings_path)
tags = pd.read_csv(tags_path)

# %% [markdown]
# ## dataset overview
# - this dataset has 4 different files that contain information of the movies, users and thier interactions
# - **the file we're interested in is the ratings file** that contains the ratings of users on the movies

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
ratings.userId.nunique(), ratings.movieId.nunique()
# Out:
# (610, 9724)

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
tags.head(20)
# Out:
#     userId  movieId                tag   timestamp
# 0        2    60756              funny  1445714994
# 1        2    60756    Highly quotable  1445714996
# 2        2    60756       will ferrell  1445714992
# 3        2    89774       Boxing story  1445715207
# 4        2    89774                MMA  1445715200
# 5        2    89774          Tom Hardy  1445715205
# 6        2   106782              drugs  1445715054
# 7        2   106782  Leonardo DiCaprio  1445715051
# 8        2   106782    Martin Scorsese  1445715056
# 9        7    48516       way too long  1169687325
# 10      18      431          Al Pacino  1462138765
# 11      18      431           gangster  1462138749
# 12      18      431              mafia  1462138755
# 13      18     1221          Al Pacino  1461699306
# 14      18     1221              Mafia  1461699303
# 15      18     5995          holocaust  1455735472
# 16      18     5995         true story  1455735479
# ...

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]
